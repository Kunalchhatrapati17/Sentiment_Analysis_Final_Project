# %%
pip install s3fs
# Out:
# ...
#
# ...

# %%
from kafka import KafkaConsumer
from time import sleep
from json import loads
import json
from s3fs import S3FileSystem

# %%
from kafka import KafkaConsumer
from json import loads

consumer = KafkaConsumer(
    'demotesting',
    bootstrap_servers='54.219.27.187:9092',
    value_deserializer=lambda x: loads(x.decode('utf-8'))
)

# %%
# for c in consumer:
#     print(c.value)

# %%
s3=S3FileSystem()

# %%
for count, i in enumerate(consumer):
    #print(count)
    #print(i.value)
    with s3.open("s3://Kunal_Account/stock_market_{].json".format(count)
         json.dump(i.value, file)
# Out:
#   Cell In[11], line 5
#     json.dump(i.value, file)
#     ^
# SyntaxError: invalid syntax

# %%
import json

for count, i in enumerate(consumer):
    with s3.open(f"s3://aws-real-time-stock-market-analysis/stock_market_{}.json", "w") as file:
        json.dump(i.value, file)

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://aws-real-time-stock-market-analysis/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://aws-real-time-stock-market-analysis/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# ...

# %%
for count, msg in enumerate(consumer):
    file_path = f"s3://aws-real-time-stock-market-analysis/stock_market_{count}.json"

    with s3.open(file_path, 'w') as file:
        json.dump(msg.value, file)

    print(f"Uploaded: {file_path}")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\aiohttp\connector.py:1574, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1570 try:
#    1571     # Cancelling this lookup should not cancel the underlying lookup
#    1572     #  or else the cancel event will get broadcast to all the waiters
#    1573     #  across all connections.
# -> 1574     hosts = await self._resolve_host(host, port, traces=traces)
#    1575 except OSError as exc:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\aiohttp\connector.py:1190, in TCPConnector._resolve_host(self, host, port, traces)
#    1189 try:
# -> 1190     return await asyncio.shield(resolved_host_task)
#    1191 except asyncio.CancelledError:
#
# ...

# %%
for count, i in enumerate(consumer):
    file_path = f"s3://aws-real-time-stock-market-analysis/stock_market_{count}.json"

    with s3.open(file_path, "w") as file:
        json.dump(i.value, file)

    print(f"Uploaded: {file_path}")
